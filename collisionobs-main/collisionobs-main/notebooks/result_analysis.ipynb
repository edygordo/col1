# %%
import sys
sys.path.append("../modules")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
nn_rmse = pd.read_csv('../nn_rmse.csv')
nn_std = pd.read_csv('../nn_std.csv')

ens_rmse = pd.read_csv('../ens_rmse.csv')
ens_std = pd.read_csv('../ens_std.csv')

xgb_rmse = pd.read_csv('../xgb_rmse.csv')
xgb_std = pd.read_csv('../xgb_std.csv')

ens_xgb_rmse = pd.read_csv('../ens_xgb_rmse.csv')
ens_xgb_std = pd.read_csv('../ens_xgb_std.csv')

# %%
ens_rmse[['x', 'y', 'z']].plot()
ens_std[['x', 'y', 'z']].plot()

# %%
ens_xgb_rmse[['x', 'y', 'z']].plot()
ens_xgb_std[['x', 'y', 'z']].plot()
